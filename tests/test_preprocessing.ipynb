# %%
import sys
sys.path.append('../pre_processing/')
from preprocessing import dataPreProcessing

# %%
preprocessing = dataPreProcessing('../../msc_dissertation_notebooks/app_route_data/trajets_mtl_trajet_2017.shp')

# %%
preprocessing = preprocessing.read_file()

# %%
preprocessing.data.head()
# Out:
#    id_trip  mode           purpose               starttime  \
# 0     1547  None              None  2017-09-18 04:16:58UTC
# 1   308312  None              None  2017-09-18 06:17:46UTC
# 2   384772  None              None  2017-09-18 09:30:24UTC
# 3   150744   car  pick_up_a_person  2017-09-18 10:02:50UTC
# 4   199011  None              None  2017-09-18 10:18:40UTC
#
#                   endtime  journeytim    distance_m  \
# 0  2017-09-18 04:26:26UTC         568   1530.222174
# 1  2017-09-18 06:58:49UTC        2463    324.869460
# 2  2017-09-18 10:17:28UTC        2824  32009.701647
# 3  2017-09-18 10:17:12UTC         862   9935.922336
# 4  2017-09-18 10:27:44UTC         544    563.806088
#
#                                             geometry
# 0  LINESTRING (7624015.797731051 1247372.35912242...
# 1  LINESTRING (7624029.565886391 1247375.82561127...
# 2  (LINESTRING (7607307.10774919 1253237.70694762...
# 3  LINESTRING (7624322.265039731 1247672.97005955...
# ...

# %%
preprocessing = preprocessing.make_translations()

# %%
preprocessing.data.head()
# Out:
#    id_trip  mode           purpose               starttime  \
# 0     1547  None              None  2017-09-18 04:16:58UTC
# 1   308312  None              None  2017-09-18 06:17:46UTC
# 2   384772  None              None  2017-09-18 09:30:24UTC
# 3   150744   car  pick_up_a_person  2017-09-18 10:02:50UTC
# 4   199011  None              None  2017-09-18 10:18:40UTC
#
#                   endtime  journeytim    distance_m  \
# 0  2017-09-18 04:26:26UTC         568   1530.222174
# 1  2017-09-18 06:58:49UTC        2463    324.869460
# 2  2017-09-18 10:17:28UTC        2824  32009.701647
# 3  2017-09-18 10:17:12UTC         862   9935.922336
# 4  2017-09-18 10:27:44UTC         544    563.806088
#
#                                             geometry
# 0  LINESTRING (7624015.797731051 1247372.35912242...
# 1  LINESTRING (7624029.565886391 1247375.82561127...
# 2  (LINESTRING (7607307.10774919 1253237.70694762...
# 3  LINESTRING (7624322.265039731 1247672.97005955...
# ...

# %%
preprocessing = preprocessing.change_projection()
# Out:
# correct crs

# %%
preprocessing.data.head()
# Out:
#    id_trip  mode           purpose               starttime  \
# 0     1547  None              None  2017-09-18 04:16:58UTC
# 1   308312  None              None  2017-09-18 06:17:46UTC
# 2   384772  None              None  2017-09-18 09:30:24UTC
# 3   150744   car  pick_up_a_person  2017-09-18 10:02:50UTC
# 4   199011  None              None  2017-09-18 10:18:40UTC
#
#                   endtime  journeytim    distance_m  \
# 0  2017-09-18 04:26:26UTC         568   1530.222174
# 1  2017-09-18 06:58:49UTC        2463    324.869460
# 2  2017-09-18 10:17:28UTC        2824  32009.701647
# 3  2017-09-18 10:17:12UTC         862   9935.922336
# 4  2017-09-18 10:27:44UTC         544    563.806088
#
#                                             geometry
# 0  LINESTRING (7624015.797731051 1247372.35912242...
# 1  LINESTRING (7624029.565886391 1247375.82561127...
# 2  (LINESTRING (7607307.10774919 1253237.70694762...
# 3  LINESTRING (7624322.265039731 1247672.97005955...
# ...

# %%
preprocessing = preprocessing.calc_journeytime()

# %%
preprocessing.data.head()
# Out:
#    id_trip  mode           purpose               starttime  \
# 0     1547  None              None  2017-09-18 04:16:58UTC
# 1   308312  None              None  2017-09-18 06:17:46UTC
# 2   384772  None              None  2017-09-18 09:30:24UTC
# 3   150744   car  pick_up_a_person  2017-09-18 10:02:50UTC
# 4   199011  None              None  2017-09-18 10:18:40UTC
#
#                   endtime  journeytime  \
# 0  2017-09-18 04:26:26UTC          568
# 1  2017-09-18 06:58:49UTC         2463
# 2  2017-09-18 10:17:28UTC         2824
# 3  2017-09-18 10:17:12UTC          862
# 4  2017-09-18 10:27:44UTC          544
#
#                                             geometry
# 0  LINESTRING (7624015.797731051 1247372.35912242...
# 1  LINESTRING (7624029.565886391 1247375.82561127...
# 2  (LINESTRING (7607307.10774919 1253237.70694762...
# 3  LINESTRING (7624322.265039731 1247672.97005955...
# 4  (LINESTRING (7616402.39358294 1246769.19969164...

# %%
preprocessing = preprocessing.calc_distance()
# Out:
# calculating distance

# %%
preprocessing.data.head()
# Out:
#    id_trip  mode           purpose               starttime  \
# 0     1547  None              None  2017-09-18 04:16:58UTC
# 1   308312  None              None  2017-09-18 06:17:46UTC
# 2   384772  None              None  2017-09-18 09:30:24UTC
# 3   150744   car  pick_up_a_person  2017-09-18 10:02:50UTC
# 4   199011  None              None  2017-09-18 10:18:40UTC
#
#                   endtime  journeytime  \
# 0  2017-09-18 04:26:26UTC          568
# 1  2017-09-18 06:58:49UTC         2463
# 2  2017-09-18 10:17:28UTC         2824
# 3  2017-09-18 10:17:12UTC          862
# 4  2017-09-18 10:27:44UTC          544
#
#                                             geometry    distance_m
# 0  LINESTRING (7624015.797731051 1247372.35912242...   1530.222174
# 1  LINESTRING (7624029.565886391 1247375.82561127...    324.869460
# 2  (LINESTRING (7607307.10774919 1253237.70694762...  32009.701647
# 3  LINESTRING (7624322.265039731 1247672.97005955...   9935.922336
# ...
