# %% [markdown]
# ## metrics & merge:
# - calc a distance, avg. speed?, directionality (N,E,S,W)
# - merge to socio-demographic data?

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
import datetime
import numpy as np
import seaborn as sns
from shapely.geometry import LineString

# %matplotlib inline

# %%
gdf = gpd.read_file("../app_route_data/trajets_mtl_trajet_2017.shp", encoding='utf-8') # utf-8 needed to read french letters

# %%
CAN_LAM = {'init': 'epsg:3347'}

# %%
gdf.plot()

# %%
gdf.head()
# Out:
#    id_trip  mode           purpose               starttime  \
# 0     1547  None              None  2017-09-18 04:16:58UTC
# 1   308312  None              None  2017-09-18 06:17:46UTC
# 2   384772  None              None  2017-09-18 09:30:24UTC
# 3   150744   car  pick_up_a_person  2017-09-18 10:02:50UTC
# 4   199011  None              None  2017-09-18 10:18:40UTC
#
#                   endtime  journeytim    distance_m  \
# 0  2017-09-18 04:26:26UTC         568   1530.222174
# 1  2017-09-18 06:58:49UTC        2463    324.869460
# 2  2017-09-18 10:17:28UTC        2824  32009.701647
# 3  2017-09-18 10:17:12UTC         862   9935.922336
# 4  2017-09-18 10:27:44UTC         544    563.806088
#
#                                             geometry
# 0  LINESTRING (7624015.797731051 1247372.35912242...
# 1  LINESTRING (7624029.565886391 1247375.82561127...
# 2  (LINESTRING (7607307.10774919 1253237.70694762...
# 3  LINESTRING (7624322.265039731 1247672.97005955...
# ...

# %%
gdf['journeytime'] = pd.to_datetime(gdf['endtime']) - pd.to_datetime(gdf['starttime'])
gdf['journeytime'] = gdf.journeytime.apply(lambda tm: tm.seconds)
# gdf[["id_trip","mode","purpose","starttime","endtime","journeytime","geometry"]].to_file("../app_route_data/trajets_mtl_trajet_2017.shp", encoding='utf-8')

# %%
gdf.info()

# %%
gdf.journeytime.describe()

# %%
sns.distplot(gdf.journeytime/60,hist=True)
plt.xlabel("journey time (mins)")

# %%
sns.kdeplot(gdf.journeytime,cumulative=True)

# %%
gdf.groupby(["purpose"]).mean().journeytime.plot.barh()

# %% [markdown]
# ## distance and projection

# %%
if gdf.crs ==

# %%
## convert to Canada Lambert Projection (https://epsg.io/3347)

# gdf = gdf.to_crs(crs=CAN_LAM)

# %%
if 'distance_m' in gdf.columns:
    print("calculating distance")
    gdf['distance_m'] = gdf['geometry'].apply(lambda row: row.length)
print('distance ')

# %%
## save file
# gdf[["id_trip","mode","purpose","starttime","endtime","journeytime","distance_m","geometry"]].to_file("../app_route_data/trajets_mtl_trajet_2017.shp", encoding='utf-8')
